# %% [markdown]
# # A simple menu-driven calculator built using Python that performs basic arithmetic operations like addition, subtraction, multiplication, and division through a command-line interface.

# %% [markdown]
# ##  Features
# - Addition
# - Subtraction
# - Multiplication
# - Division
# - Continuous calculation until user exits
# - Clean menu-driven interface

# %% [markdown]
# ## THIS IS THE BASIC VERSION IN WHICH ONLY CONDITIONAL STATEMENTS ARE BEING :

# %%
num1 = int(input("enetr first number"))
oprtr = input("enter your operator")
num2 = int(input("enter second number"))
if oprtr == "+" :
    print("ADIITION OF",num1,"AND",num2,"=",num1+num2)
elif oprtr == "-":
    print("SUBTRACTION OF",num1,"AND",num2,"=",num1-num2)
elif oprtr == "/":
    if b == 0:
        print("IN DIVISION SECOND NUMBER CANNOT BE ZERO")
    else:
        print("DIVISION OF",num1,"AND",num2,"=",num1/num2)
elif oprtr == "*":
    print("MULTIPLICATION OF",num1,"AND",num2,"=",num1*num2)
else:
    print("INVALID OPERATOR USED")
# Out:
# enetr first number 50
# enter your operator -
# enter second number 40
# SUBTRACTION OF 50 AND 40 = 10

# %% [markdown]
# ## THE ADVANCED ONE IN WHICH CONDITIONAL STATEMENTS, LOOPS AND FUNCTIONS ARE BEING USED :

# %%
def addition(num1,num2 = 0):
    return (num1+num2)
    
def subtraction(num1,num2 = 0):
    return (num1-num2)
    
def multiplication(num1,num2 = 0):
    return (num1*num2)
    
def division(num1,num2):
    if num2 == 0:
        return("IN DIVISION SECOND NUMBER CANNOT BE ZERO")
    else:
        return num1%num2

while True:
    print("WELCOME TO PYTHON MINI CALCULATOR")
    print("PRESS A FOR ADDITION")
    print("PRESS S FOR SUBTRACTION")
    print("PRESS M FOR MULTIPLICATION")
    print("PRESS D FOR DIVISION")
    print("PRESS E FOR EXIT")
   
    selection = ["A","S","M","D"]
    user = input("ENTER YOUR CHOICE OF ACTIVITY HERE").upper()
    if user in selection:
        num1 = int(input("SELECT FIRST NUMBER "))
        num2 = int(input("SELECT SECOND NUMBER"))
    
    if user == "A" :
        print("ADDITION RESULT : " , addition(num1,num2))
    elif user == "S":
        print("SUBTRACTION RESULT: " , subtraction(num1,num2))
    elif user == "M":
        print("MULTPLICATION RESULT: " , multiplication(num1,num2))
    elif user == "D":
        print("DIVISION RESULT : " , division(num1,num2))
    elif user == "E":
        print("THANKS FOR USING THIS CALCULATOR")
        break
    else:
        print("INVALID CHOICE SELECTED BY THE USER")
# Out:
# WELCOME TO PYTHON MINI CALCULATOR
# PRESS A FOR ADDITION
# PRESS S FOR SUBTRACTION
# PRESS M FOR MULTIPLICATION
# PRESS D FOR DIVISION
# PRESS E FOR EXIT
# ENTER YOUR CHOICE OF ACTIVITY HERE e
# THANKS FOR USING THIS CALCULATOR
